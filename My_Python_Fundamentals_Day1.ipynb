# %%
print("Welcome To My Python World")
# Out:
# Welcome To My Python World

# %%
print("This is my first day of Learing the Python Fundamentals")
# Out:
# This is my first day of Learing the Python Fundamentals
